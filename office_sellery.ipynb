# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
dt = {
    "Name":["rahul","aman","rohit","neha","priya"],
    "Dipartment":["IT","IT","HR","HR","IT"],
    "Year":[2023,2024,2023,2024,2023],
    "Salary":[50000,60000,45000,55000,70000]
}
df = pd.DataFrame(dt)
df["Name"] = df["Name"].str.title()

# %%
df.sample(2)
# Out:
#     Name Dipartment  Year  Salary
# 1   Aman         IT  2024   60000
# 0  Rahul         IT  2023   50000

# %%
dt =df.pivot_table(
    values="Salary",
    index="Dipartment",
    columns="Year",
    aggfunc="mean",
   
    
    
)
print(dt)
# Out:
# Year           2023     2024
# Dipartment
# HR          45000.0  55000.0
# IT          60000.0  60000.0

# %%
#dt= df.pivot(index = "Name",Coulmns = 'Year')["Salary"].max()

# %%
#df.pivot(index ='Dipartment',columns='Year')["Salary"]
#df.pivot(index ='Dipartment',columns='Year')["Salary"]

# %%
df[df.duplicated(subset=["Dipartment", "Year"], keep=False)]
# Out:
#     Name Dipartment  Year  Salary
# 0  Rahul         IT  2023   50000
# 4  Priya         IT  2023   70000

# %%
df.to_excel("Office_Sellery.xlsx",index=False)

# %%
#data_2 = {
#    "Age":[20,25,30,35,40]
#}
#dff = pd.DataFrame(data)
#print(dff)

# %%
df.sample(2)
# Out:
#     Name Dipartment  Year  Salary
# 0  Rahul         IT  2023   50000
# 4  Priya         IT  2023   70000

# %%
from scipy import stats
import seaborn as sns
flights = sns.load_dataset("flights")
print(flights)
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
#X = df[["Dipartment"]]
#y = df["Salary"] 

#model = Linear_Regression
#model.fit(X,y)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.regplot(x="Dipartment",y="Salary",data=dt)

plt.ylim(0,)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:175, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Dipartment'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 3
#       1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
# ----> 3 sns.regplot(x="Dipartment",y="Salary",data=dt)
#       5 plt.ylim(0,)
#
# ...
